# %%
import pandas as pd
import numpy as np
import random
import json
import pickle

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, make_scorer, f1_score, classification_report, confusion_matrix, roc_auc_score
from sklearn.preprocessing import LabelEncoder, StandardScaler

from imblearn.under_sampling import RandomUnderSampler, ClusterCentroids
from collections import Counter

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

from bayes_opt import BayesianOptimization
from sklearn.pipeline import Pipeline

import warnings
warnings.filterwarnings('ignore')

SEED = 42

random.seed(SEED)
np.random.seed(SEED)

# %%
df_raw = pd.read_csv('../df_clean.csv', index_col=0)

df_raw.head()
# Out:
#         category     amt gender  is_fraud  transaction_month  transaction_day  \
# 0       misc_net    4.97      F         0                  1                1
# 1    grocery_pos  107.23      F         0                  1                1
# 2  entertainment  220.11      M         0                  1                1
# 3  gas_transport   45.00      M         0                  1                1
# 4       misc_pos   41.96      M         0                  1                1
#
#    transaction_hour  transaction_day_of_week  transaction_is_weekend  age  \
# 0                 0                        1                       0   30
# 1                 0                        1                       0   40
# 2                 0                        1                       0   56
# 3                 0                        1                       0   51
# 4                 0                        1                       0   32
#
#   time_category
# 0      midnight
# 1      midnight
# 2      midnight
# 3      midnight
# 4      midnight

# %%
df_raw.drop(['gender'], axis=1, inplace=True)
df_raw
# Out:
#               category     amt  is_fraud  transaction_month  transaction_day  \
# 0             misc_net    4.97         0                  1                1
# 1          grocery_pos  107.23         0                  1                1
# 2        entertainment  220.11         0                  1                1
# 3        gas_transport   45.00         0                  1                1
# 4             misc_pos   41.96         0                  1                1
# ...                ...     ...       ...                ...              ...
# 1296670  entertainment   15.56         0                  6               21
# 1296671    food_dining   51.70         0                  6               21
# 1296672    food_dining  105.93         0                  6               21
# 1296673    food_dining   74.90         0                  6               21
# 1296674    food_dining    4.30         0                  6               21
#
#          transaction_hour  transaction_day_of_week  transaction_is_weekend  \
# 0                       0                        1                       0
# 1                       0                        1                       0
# 2                       0                        1                       0
# 3                       0                        1                       0
# 4                       0                        1                       0
# ...                   ...                      ...                     ...
# 1296670                12                        6                       1
# 1296671                12                        6                       1
# 1296672                12                        6                       1
# 1296673                12                        6                       1
# 1296674                12                        6                       1
#
#          age time_category
# 0         30      midnight
# 1         40      midnight
# 2         56      midnight
# 3         51      midnight
# 4         32      midnight
# ...      ...           ...
# 1296670   58     afternoon
# 1296671   40     afternoon
# 1296672   52     afternoon
# 1296673   39     afternoon
# 1296674   24     afternoon
#
# [1296675 rows x 10 columns]

# %%
df = pd.get_dummies(df_raw, columns=['category'], prefix='cat')
df
# Out:
#             amt  is_fraud  transaction_month  transaction_day  \
# 0          4.97         0                  1                1
# 1        107.23         0                  1                1
# 2        220.11         0                  1                1
# 3         45.00         0                  1                1
# 4         41.96         0                  1                1
# ...         ...       ...                ...              ...
# 1296670   15.56         0                  6               21
# 1296671   51.70         0                  6               21
# 1296672  105.93         0                  6               21
# 1296673   74.90         0                  6               21
# 1296674    4.30         0                  6               21
#
#          transaction_hour  transaction_day_of_week  transaction_is_weekend  \
# 0                       0                        1                       0
# 1                       0                        1                       0
# 2                       0                        1                       0
# 3                       0                        1                       0
# 4                       0                        1                       0
# ...                   ...                      ...                     ...
# 1296670                12                        6                       1
# 1296671                12                        6                       1
# 1296672                12                        6                       1
# 1296673                12                        6                       1
# 1296674                12                        6                       1
#
#          age time_category  cat_entertainment  ...  cat_grocery_pos  \
# 0         30      midnight              False  ...            False
# 1         40      midnight              False  ...             True
# 2         56      midnight               True  ...            False
# 3         51      midnight              False  ...            False
# 4         32      midnight              False  ...            False
# ...      ...           ...                ...  ...              ...
# 1296670   58     afternoon               True  ...            False
# 1296671   40     afternoon              False  ...            False
# 1296672   52     afternoon              False  ...            False
# 1296673   39     afternoon              False  ...            False
# 1296674   24     afternoon              False  ...            False
#
#          cat_health_fitness  cat_home  cat_kids_pets  cat_misc_net  \
# 0                     False     False          False          True
# 1                     False     False          False         False
# 2                     False     False          False         False
# 3                     False     False          False         False
# 4                     False     False          False         False
# ...                     ...       ...            ...           ...
# 1296670               False     False          False         False
# 1296671               False     False          False         False
# 1296672               False     False          False         False
# 1296673               False     False          False         False
# 1296674               False     False          False         False
#
#          cat_misc_pos  cat_personal_care  cat_shopping_net  cat_shopping_pos  \
# 0               False              False             False             False
# 1               False              False             False             False
# 2               False              False             False             False
# 3               False              False             False             False
# 4                True              False             False             False
# ...               ...                ...               ...               ...
# 1296670         False              False             False             False
# 1296671         False              False             False             False
# 1296672         False              False             False             False
# 1296673         False              False             False             False
# 1296674         False              False             False             False
#
#          cat_travel
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 1296670       False
# 1296671       False
# 1296672       False
# 1296673       False
# 1296674       False
#
# [1296675 rows x 23 columns]

# %%
# Plotting kategori waktu untuk fraud
df_fraud = df[df.is_fraud == 1]
plt.figure(figsize=(8, 6))
sns.countplot(x='time_category', data=df_fraud, palette='Set2')
plt.title('Distribusi Kategori Waktu Transaksi untuk Fraud')
plt.xlabel('Kategori Waktu')
plt.ylabel('Jumlah Transaksi Fraud')
# Out:
# Text(0, 0.5, 'Jumlah Transaksi Fraud')

# %%
# Hitung distribusi persentase kategori
category_percentage = df[df.is_fraud == 1]['time_category'].value_counts(normalize=True)

# Buat dictionary untuk label encoding berdasarkan persentase distribusi
label_encoding = {category: percentage for category, percentage in category_percentage.items()}

# Terapkan label encoding ke kolom time_category
df['time_category_encoded'] = df['time_category'].map(label_encoding)

df.drop(['time_category'], axis=1, inplace=True)
df
# Out:
#             amt  is_fraud  transaction_month  transaction_day  \
# 0          4.97         0                  1                1
# 1        107.23         0                  1                1
# 2        220.11         0                  1                1
# 3         45.00         0                  1                1
# 4         41.96         0                  1                1
# ...         ...       ...                ...              ...
# 1296670   15.56         0                  6               21
# 1296671   51.70         0                  6               21
# 1296672  105.93         0                  6               21
# 1296673   74.90         0                  6               21
# 1296674    4.30         0                  6               21
#
#          transaction_hour  transaction_day_of_week  transaction_is_weekend  \
# 0                       0                        1                       0
# 1                       0                        1                       0
# 2                       0                        1                       0
# 3                       0                        1                       0
# 4                       0                        1                       0
# ...                   ...                      ...                     ...
# 1296670                12                        6                       1
# 1296671                12                        6                       1
# 1296672                12                        6                       1
# 1296673                12                        6                       1
# 1296674                12                        6                       1
#
#          age  cat_entertainment  cat_food_dining  ...  cat_health_fitness  \
# 0         30              False            False  ...               False
# 1         40              False            False  ...               False
# 2         56               True            False  ...               False
# 3         51              False            False  ...               False
# 4         32              False            False  ...               False
# ...      ...                ...              ...  ...                 ...
# 1296670   58               True            False  ...               False
# 1296671   40              False             True  ...               False
# 1296672   52              False             True  ...               False
# 1296673   39              False             True  ...               False
# 1296674   24              False             True  ...               False
#
#          cat_home  cat_kids_pets  cat_misc_net  cat_misc_pos  \
# 0           False          False          True         False
# 1           False          False         False         False
# 2           False          False         False         False
# 3           False          False         False         False
# 4           False          False         False          True
# ...           ...            ...           ...           ...
# 1296670     False          False         False         False
# 1296671     False          False         False         False
# 1296672     False          False         False         False
# 1296673     False          False         False         False
# 1296674     False          False         False         False
#
#          cat_personal_care  cat_shopping_net  cat_shopping_pos  cat_travel  \
# 0                    False             False             False       False
# 1                    False             False             False       False
# 2                    False             False             False       False
# 3                    False             False             False       False
# 4                    False             False             False       False
# ...                    ...               ...               ...         ...
# 1296670              False             False             False       False
# 1296671              False             False             False       False
# 1296672              False             False             False       False
# 1296673              False             False             False       False
# 1296674              False             False             False       False
#
#          time_category_encoded
# 0                     0.863576
# 1                     0.863576
# 2                     0.863576
# 3                     0.863576
# 4                     0.863576
# ...                        ...
# 1296670               0.051692
# 1296671               0.051692
# 1296672               0.051692
# 1296673               0.051692
# 1296674               0.051692
#
# [1296675 rows x 23 columns]

# %%
# Pisahkan X (fitur) dan y (target)
X = df.drop(columns=['is_fraud'])
y = df['is_fraud']

# Split data menjadi training dan testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=SEED, stratify=y)

# %%
scaler = StandardScaler()
numerical_features = ['amt','age']

# %%
# Random Undersampling
random_undersampler = RandomUnderSampler(random_state=SEED)
X_train_ru, y_train_ru = random_undersampler.fit_resample(X, y)

# Scaling setelah oversampling (fit pada data training)
X_train_ru[numerical_features] = scaler.fit_transform(X_train_ru[numerical_features])

# %%
# Cluster Centroids Undersampling
cluster_centroids_undersampler = ClusterCentroids(random_state=SEED)
X_train_cc, y_train_cc = cluster_centroids_undersampler.fit_resample(X, y)

# Scaling setelah oversampling (fit pada data training)
X_train_cc[numerical_features] = scaler.fit_transform(X_train_cc[numerical_features])

# %%
# Scaling data test (transform tanpa fit ulang)
X_test[numerical_features] = scaler.transform(X_test[numerical_features])

# scaling untuk data train tanpa oversampling
X_train[numerical_features] = scaler.fit_transform(X_train[numerical_features])

# %%
def build_train_model(method, model_name, params):
    model = None
    if model_name == 'adaboost':
        model = AdaBoostClassifier(n_estimators=int(params['n_estimators']), learning_rate=params['learning_rate'])
    elif model_name == 'random_forest':
        model = RandomForestClassifier(n_estimators=int(params['n_estimators']), max_depth=int(params['max_depth']))
    elif model_name == 'decision_tree':
        model = DecisionTreeClassifier(max_depth=int(params['max_depth']), min_samples_split=int(params['min_samples_split']))
    elif model_name == 'logistic_regression':
        model = LogisticRegression(C=params['C'], solver='liblinear')
    else:
        raise ValueError("Unknown model")

    # chose training set
    X_resampled, y_resampled = None, None
    if method is None or method == 'no_oversampling':
        X_resampled, y_resampled = X_train, y_train
    elif method == 'random':
        X_resampled, y_resampled = X_train_ru, y_train_ru
    elif method == 'cluster_centroids':
        X_resampled, y_resampled = X_train_cc, y_train_cc
    else:
        raise ValueError("Unknown method")

    # perform training
    model.fit(X_resampled, y_resampled)
    return model

# %%
# Objective Function for Bayesian Optimization
def optimize_model(method, model_name, params):
    model = build_train_model(method, model_name, params)

    # Predict on test set
    y_pred = model.predict(X_test)
    
    # Return accuracy as score
    score = accuracy_score(y_test, y_pred)
    
    return score

# %%
def run_bayesian_optimization(model_name, method, pbounds):
    optimizer = BayesianOptimization(
        f=lambda **params: optimize_model(method, model_name, params),
        pbounds=pbounds,
        random_state=SEED,
        verbose=2
    )
    optimizer.maximize(init_points=5, n_iter=5)
    return optimizer

# %%
def save_best_params_to_json(best_params, filename="best_params.json"):
    with open(filename, 'w') as json_file:
        json.dump(best_params, json_file, indent=4)
    print(f"Best parameters saved to {filename}")

# %%
def save_model_to_file(model, filename="model.pkl"):
    with open(filename,'wb') as f:
        pickle.dump(model,f)

# %%
# Parameter Bounds for model
params_adaboost = {
    'n_estimators': (50, 500),
    'learning_rate': (0.01, 1)
}

params_random_forest = {
    'n_estimators': (50, 500),
    'max_depth': (5, 30)
}

params_decision_tree = {
    'max_depth': (5, 30),
    'min_samples_split': (2, 10)
}

params_logistic_regression = {
    'C': (0.01, 10)
}

MODEL_DICT = {
    'adaboost': {
        'pbounds': params_adaboost,
    },
    'random_forest': {
        'pbounds': params_random_forest,
    },
    'decision_tree': {
        'pbounds': params_decision_tree,
    },
    'logistic_regression': {
        'pbounds': params_logistic_regression,
    },
}

model_list = ['decision_tree','logistic_regression','adaboost','random_forest']
method_list = ['random','cluster_centroids']

# %%
# hyperparameter tuning for each model and oversampling method

for model_name in model_list:
    MODEL_DICT[model_name]['params'] = {}
    pbounds = MODEL_DICT[model_name]['pbounds']
    for method in method_list:
        print(f"Finding best parameters for {model_name} with {method}")
        optimizer = run_bayesian_optimization(model_name, method=method, pbounds=pbounds)
        best_params = optimizer.max['params']
        print(f"Best parameters for {model_name} with {method}: ", best_params)
        save_best_params_to_json(best_params, filename=f"best_params_{model_name}_{method}.json")
        MODEL_DICT[model_name]['params'][method] = best_params
# Out:
# Finding best parameters for decision_tree with random
# |   iter    |  target   | max_depth | min_sa... |
# -------------------------------------------------
# | 1         | 0.9837    | 14.36     | 9.606     |
# | 2         | 0.9827    | 23.3      | 6.789     |
# | 3         | 0.9725    | 8.9       | 3.248     |
# | 4         | 0.9722    | 6.452     | 8.929     |
# | 5         | 0.9827    | 20.03     | 7.665     |
# | 6         | 0.9837    | 30.0      | 10.0      |
# | 7         | 0.9757    | 30.0      | 2.0       |
# | 8         | 0.9834    | 24.91     | 10.0      |
# | 9         | 0.9776    | 18.64     | 2.0       |
# | 10        | 0.9846    | 17.58     | 10.0      |
# =================================================
# Best parameters for decision_tree with random:  {'max_depth': 17.58256675992068, 'min_samples_split': 10.0}
# Best parameters saved to best_params_decision_tree_random.json
# Finding best parameters for decision_tree with cluster_centroids
# |   iter    |  target   | max_depth | min_sa... |
# -------------------------------------------------
# | 1         | 0.00874   | 14.36     | 9.606     |
# | 2         | 0.00874   | 23.3      | 6.789     |
# | 3         | 0.008761  | 8.9       | 3.248     |
# | 4         | 0.009632  | 6.452     | 8.929     |
# | 5         | 0.00874   | 20.03     | 7.665     |
# | 6         | 0.01967   | 5.0       | 10.0      |
# | 7         | 0.008769  | 24.76     | 2.969     |
# | 8         | 0.01967   | 5.005     | 9.995     |
# | 9         | 0.01967   | 5.0       | 8.916     |
# | 10        | 0.01967   | 5.0       | 6.653     |
# =================================================
# Best parameters for decision_tree with cluster_centroids:  {'max_depth': 5.0, 'min_samples_split': 10.0}
# Best parameters saved to best_params_decision_tree_cluster_centroids.json
# Finding best parameters for logistic_regression with random
# |   iter    |  target   |     C     |
# -------------------------------------
# | 1         | 0.7797    | 3.752     |
# | 2         | 0.7795    | 9.508     |
# | 3         | 0.7796    | 7.323     |
# | 4         | 0.7796    | 5.991     |
# | 5         | 0.7801    | 1.569     |
# | 6         | 0.7785    | 0.01      |
# | 7         | 0.7801    | 1.572     |
# | 8         | 0.7796    | 4.812     |
# | 9         | 0.7804    | 1.054     |
# | 10        | 0.7798    | 2.667     |
# =====================================
# Best parameters for logistic_regression with random:  {'C': 1.0544894872468669}
# Best parameters saved to best_params_logistic_regression_random.json
# Finding best parameters for logistic_regression with cluster_centroids
# |   iter    |  target   |     C     |
# -------------------------------------
# | 1         | 0.006257  | 3.752     |
# | 2         | 0.00627   | 9.508     |
# | 3         | 0.006272  | 7.323     |
# | 4         | 0.006272  | 5.991     |
# | 5         | 0.006216  | 1.569     |
# | 6         | 0.006275  | 8.444     |
# | 7         | 0.00627   | 5.06      |
# | 8         | 0.006275  | 8.048     |
# | 9         | 0.006275  | 8.248     |
# | 10        | 0.006275  | 8.814     |
# =====================================
# Best parameters for logistic_regression with cluster_centroids:  {'C': 8.443681129608569}
# Best parameters saved to best_params_logistic_regression_cluster_centroids.json
# Finding best parameters for adaboost with random
# |   iter    |  target   | learni... | n_esti... |
# -------------------------------------------------
# | 1         | 0.9362    | 0.3808    | 477.8     |
# | 2         | 0.9355    | 0.7347    | 319.4     |
# | 3         | 0.9763    | 0.1645    | 120.2     |
# | 4         | 0.9782    | 0.0675    | 439.8     |
# | 5         | 0.9349    | 0.6051    | 368.6     |
# | 6         | 0.9432    | 0.8618    | 440.6     |
# | 7         | 0.9287    | 0.7926    | 104.5     |
# | 8         | 0.9785    | 0.06331   | 439.8     |
# | 9         | 0.971     | 0.349     | 121.0     |
# | 10        | 0.9341    | 1.0       | 120.1     |
# =================================================
# Best parameters for adaboost with random:  {'learning_rate': 0.06330547779580686, 'n_estimators': 439.78820565779705}
# Best parameters saved to best_params_adaboost_random.json
# Finding best parameters for adaboost with cluster_centroids
# |   iter    |  target   | learni... | n_esti... |
# -------------------------------------------------
# | 1         | 0.006954  | 0.3808    | 477.8     |
# | 2         | 0.006954  | 0.7347    | 319.4     |
# | 3         | 0.006954  | 0.1645    | 120.2     |
# | 4         | 0.006954  | 0.0675    | 439.8     |
# | 5         | 0.006954  | 0.6051    | 368.6     |
# | 6         | 0.006954  | 0.7679    | 50.01     |
# | 7         | 0.006954  | 0.6934    | 50.02     |
# | 8         | 0.006954  | 0.9632    | 500.0     |
# | 9         | 0.006954  | 0.3652    | 50.06     |
# | 10        | 0.006954  | 0.02621   | 499.9     |
# =================================================
# Best parameters for adaboost with cluster_centroids:  {'learning_rate': 0.3807947176588889, 'n_estimators': 477.8214378844623}
# Best parameters saved to best_params_adaboost_cluster_centroids.json
# Finding best parameters for random_forest with random
# |   iter    |  target   | max_depth | n_esti... |
# -------------------------------------------------
# | 1         | 0.9824    | 14.36     | 477.8     |
# | 2         | 0.9826    | 23.3      | 319.4     |
# | 3         | 0.9707    | 8.9       | 120.2     |
# | 4         | 0.9574    | 6.452     | 439.8     |
# | 5         | 0.9819    | 20.03     | 368.6     |
# | 6         | 0.9825    | 22.41     | 318.2     |
# | 7         | 0.9823    | 30.0      | 500.0     |
# | 8         | 0.9476    | 5.0       | 342.1     |
# | 9         | 0.9708    | 8.797     | 497.1     |
# | 10        | 0.9819    | 30.0      | 482.2     |
# =================================================
# Best parameters for random_forest with random:  {'max_depth': 23.299848545285126, 'n_estimators': 319.3963178886665}
# Best parameters saved to best_params_random_forest_random.json
# Finding best parameters for random_forest with cluster_centroids
# |   iter    |  target   | max_depth | n_esti... |
# -------------------------------------------------
# | 1         | 0.006625  | 14.36     | 477.8     |
# | 2         | 0.006591  | 23.3      | 319.4     |
# | 3         | 0.006545  | 8.9       | 120.2     |
# | 4         | 0.006658  | 6.452     | 439.8     |
# | 5         | 0.006717  | 20.03     | 368.6     |
# | 6         | 0.006632  | 20.03     | 367.5     |
# | 7         | 0.006686  | 19.24     | 368.4     |
# | 8         | 0.006645  | 19.56     | 369.7     |
# | 9         | 0.006655  | 21.15     | 369.4     |
# | 10        | 0.006707  | 20.85     | 368.5     |
# =================================================
# Best parameters for random_forest with cluster_centroids:  {'max_depth': 20.02787529358022, 'n_estimators': 368.63266000822045}
# Best parameters saved to best_params_random_forest_cluster_centroids.json

# %%
# build and train each model and oversampling method

for model_name in MODEL_DICT:
    params = MODEL_DICT[model_name]['params']
    MODEL_DICT[model_name]['models'] = {}
    for method in params:
        print(f"Building and training model {model_name} with {method}")
        best_parameters = params[method]
        model = build_train_model(method, model_name, best_parameters)
        save_model_to_file(model, f"{model_name}_{method}.pkl")
        MODEL_DICT[model_name]['models'][method] = model
# Out:
# Building and training model adaboost with random
# Building and training model adaboost with cluster_centroids
# Building and training model random_forest with random
# Building and training model random_forest with cluster_centroids
# Building and training model decision_tree with random
# Building and training model decision_tree with cluster_centroids
# Building and training model logistic_regression with random
# Building and training model logistic_regression with cluster_centroids

# %%
# make predictions

for model_name in MODEL_DICT:
    methods = MODEL_DICT[model_name]['models']
    MODEL_DICT[model_name]['predictions'] = {}
    for method in methods:
        print(f"Making predictions model {model_name} with {method}")
        model = methods[method]
        y_pred = model.predict(X_test)
        MODEL_DICT[model_name]['predictions'][method] = y_pred
# Out:
# Making predictions model adaboost with random
# Making predictions model adaboost with cluster_centroids
# Making predictions model random_forest with random
# Making predictions model random_forest with cluster_centroids
# Making predictions model decision_tree with random
# Making predictions model decision_tree with cluster_centroids
# Making predictions model logistic_regression with random
# Making predictions model logistic_regression with cluster_centroids

# %%
# show confusion matrix
for model_name in MODEL_DICT:
    methods = MODEL_DICT[model_name]['predictions']
    MODEL_DICT[model_name]['confusion_matrix'] = {}
    for method in methods:
        y_pred = methods[method]
        cm = confusion_matrix(y_test, y_pred)
        MODEL_DICT[model_name]['confusion_matrix'][method] = cm

        # Visualisasi Confusion Matrix
        plt.figure(figsize=(6,4))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Non-Fraud', 'Fraud'], yticklabels=['Non-Fraud', 'Fraud'])
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title(f"Confusion Matrix {model_name} with {method}")
        plt.savefig(f"confusion_matrix_{model_name}_{method}")
        plt.show()

# %%
def save_report_to_json(cl_report, filename="cl_report.json"):
    with open(filename, 'w') as json_file:
        json.dump(cl_report, json_file, indent=4)
    print(f"Classification Report saved to {filename}")

# %%
# show classification report
for model_name in MODEL_DICT:
    methods = MODEL_DICT[model_name]['predictions']
    MODEL_DICT[model_name]['classification_reports'] = {}
    for method in methods:
        y_pred = methods[method]
        cl_report = classification_report(y_test, y_pred, output_dict=True)
        save_report_to_json(cl_report, f"cl_report_{model_name}_{method}.json")
        cl_report_df = pd.DataFrame(cl_report).transpose()
        MODEL_DICT[model_name]['classification_reports'][method] = cl_report

        # Visualisasi laporan klasifikasi
        plt.figure(figsize=(10,6))
        sns.heatmap(cl_report_df.iloc[:-1, :-1], annot=True, cmap='Blues', fmt='.2f')
        plt.title(f"Classification Report {model_name} with {method}")
        plt.savefig(f"classification_report_{model_name}_{method}")
        plt.show()
# Out:
# Classification Report saved to cl_report_adaboost_random.json
# Classification Report saved to cl_report_adaboost_cluster_centroids.json
# Classification Report saved to cl_report_random_forest_random.json
# Classification Report saved to cl_report_random_forest_cluster_centroids.json
# Classification Report saved to cl_report_decision_tree_random.json
# Classification Report saved to cl_report_decision_tree_cluster_centroids.json
# Classification Report saved to cl_report_logistic_regression_random.json
# Classification Report saved to cl_report_logistic_regression_cluster_centroids.json

# %%
# show accuracy scores
for model_name in MODEL_DICT:
    methods = MODEL_DICT[model_name]['predictions']
    MODEL_DICT[model_name]['accuracy_scores'] = {}
    for method in methods:
        y_pred = methods[method]
        acc_score = accuracy_score(y_test, y_pred)
        MODEL_DICT[model_name]['accuracy_scores'][method] = acc_score
        print(f"Accuracy {model_name} with {method}: ", acc_score)
# Out:
# Accuracy adaboost with random:  0.9784834564257859
# Accuracy adaboost with cluster_centroids:  0.006953673879121755
# Accuracy random_forest with random:  0.9823626038873736
# Accuracy random_forest with cluster_centroids:  0.006616915550779814
# Accuracy decision_tree with random:  0.9834242923576425
# Accuracy decision_tree with cluster_centroids:  0.019665658105464483
# Accuracy logistic_regression with random:  0.7804130045269574
# Accuracy logistic_regression with cluster_centroids:  0.006275015873913569

# %%
# Create a dictionary with the data
data_scores = {
    'Model': [],
    'Oversampling Method': [],
    'Accuracy Score': []
}

for model_name in MODEL_DICT:
    methods = MODEL_DICT[model_name]['accuracy_scores']
    for method in methods:
        acc_scores = methods[method]
        data_scores['Model'].append(model_name)
        data_scores['Oversampling Method'].append(method)
        data_scores['Accuracy Score'].append(acc_scores)

# Convert the dictionary to a DataFrame
accuracy_df = pd.DataFrame(data_scores)
accuracy_df
# Out:
#                  Model Oversampling Method  Accuracy Score
# 0             adaboost              random        0.978483
# 1             adaboost   cluster_centroids        0.006954
# 2        random_forest              random        0.982363
# 3        random_forest   cluster_centroids        0.006617
# 4        decision_tree              random        0.983424
# 5        decision_tree   cluster_centroids        0.019666
# 6  logistic_regression              random        0.780413
# 7  logistic_regression   cluster_centroids        0.006275

# %%
accuracy_df.to_csv('accuracy_scores.csv', index=False)

# %%
data_cl_report = {}

for model_name in MODEL_DICT:
    methods = MODEL_DICT[model_name]['classification_reports']
    for method in methods:
        cl_report = methods[method]
        data_cl_report[f"{model_name}_{method}"] = cl_report

# Mengubah hasil evaluasi menjadi pandas DataFrame
data_cl_report_df = pd.DataFrame.from_dict({
    (model, metric): values 
    for model, metrics in data_cl_report.items() 
    for metric, values in metrics.items() if metric != 'accuracy'
}, orient='index')

data_cl_report_df
# Out:
#                                                     precision    recall  \
# adaboost_random                       0              0.998438  0.979891
#                                       1              0.175816  0.736679
#                                       macro avg      0.587127  0.858285
#                                       weighted avg   0.993675  0.978483
# adaboost_cluster_centroids            0              1.000000  0.001171
#                                       1              0.005796  1.000000
#                                       macro avg      0.502898  0.500586
#                                       weighted avg   0.994244  0.006954
# random_forest_random                  0              0.998358  0.983879
#                                       1              0.206844  0.722025
#                                       macro avg      0.602601  0.852952
#                                       weighted avg   0.993775  0.982363
# random_forest_cluster_centroids       0              1.000000  0.000833
#                                       1              0.005794  1.000000
#                                       macro avg      0.502897  0.500416
#                                       weighted avg   0.994244  0.006617
# decision_tree_random                  0              0.995880  0.987413
#                                       1              0.121300  0.298401
#                                       macro avg      0.558590  0.642907
#                                       weighted avg   0.990817  0.983424
# decision_tree_cluster_centroids       0              0.999630  0.013962
#                                       1              0.005865  0.999112
#                                       macro avg      0.502748  0.506537
#                                       weighted avg   0.993877  0.019666
# logistic_regression_random            0              0.998891  0.780001
#                                       1              0.022034  0.851243
#                                       macro avg      0.510462  0.815622
#                                       weighted avg   0.993236  0.780413
# logistic_regression_cluster_centroids 0              1.000000  0.000489
#                                       1              0.005792  1.000000
#                                       macro avg      0.502896  0.500244
#                                       weighted avg   0.994244  0.006275
#
#                                                     f1-score   support
# adaboost_random                       0             0.989078  386751.0
#                                       1             0.283881    2252.0
#                                       macro avg     0.636479  389003.0
#                                       weighted avg  0.984995  389003.0
# adaboost_cluster_centroids            0             0.002340  386751.0
#                                       1             0.011525    2252.0
#                                       macro avg     0.006932  389003.0
#                                       weighted avg  0.002393  389003.0
# random_forest_random                  0             0.991065  386751.0
#                                       1             0.321566    2252.0
#                                       macro avg     0.656316  389003.0
#                                       weighted avg  0.987189  389003.0
# random_forest_cluster_centroids       0             0.001664  386751.0
#                                       1             0.011521    2252.0
#                                       macro avg     0.006592  389003.0
#                                       weighted avg  0.001721  389003.0
# decision_tree_random                  0             0.991628  386751.0
#                                       1             0.172485    2252.0
#                                       macro avg     0.582056  389003.0
#                                       weighted avg  0.986886  389003.0
# decision_tree_cluster_centroids       0             0.027540  386751.0
#                                       1             0.011662    2252.0
#                                       macro avg     0.019601  389003.0
#                                       weighted avg  0.027448  389003.0
# logistic_regression_random            0             0.875979  386751.0
#                                       1             0.042956    2252.0
#                                       macro avg     0.459467  389003.0
#                                       weighted avg  0.871156  389003.0
# logistic_regression_cluster_centroids 0             0.000977  386751.0
#                                       1             0.011517    2252.0
#                                       macro avg     0.006247  389003.0
#                                       weighted avg  0.001038  389003.0

# %%
data_cl_report_df.to_csv('classification_report.csv', index=False)

# %%
# Mengambil data untuk precision, recall, dan f1-score dari kelas fraud (1)
precision_1 = {model: metrics['1']['precision'] for model, metrics in data_cl_report.items()}
recall_1 = {model: metrics['1']['recall'] for model, metrics in data_cl_report.items()}
f1_score_1 = {model: metrics['1']['f1-score'] for model, metrics in data_cl_report.items()}

# Membuat DataFrame untuk visualisasi
df_plot_class_1 = pd.DataFrame({
    'Model': list(precision_1.keys()),
    'Precision': list(precision_1.values()),
    'Recall': list(recall_1.values()),
    'F1-score': list(f1_score_1.values())
})

# Plot menggunakan seaborn
df_plot_class_1_melt = df_plot_class_1.melt('Model', var_name='Metric', value_name='Score')
plt.figure(figsize=(30, 6))
sns.barplot(x='Model', y='Score', hue='Metric', data=df_plot_class_1_melt)
plt.title('Comparison of Precision, Recall, and F1-score for Fraud Detection (Class 1)')
plt.savefig('comparison_report_class_1')
plt.show()

# %%
# Mengambil data untuk precision, recall, dan f1-score dari kelas non-fraud (0)
precision_0 = {model: metrics['0']['precision'] for model, metrics in data_cl_report.items()}
recall_0 = {model: metrics['0']['recall'] for model, metrics in data_cl_report.items()}
f1_score_0 = {model: metrics['0']['f1-score'] for model, metrics in data_cl_report.items()}

# Membuat DataFrame untuk visualisasi
df_plot_class_0 = pd.DataFrame({
    'Model': list(precision_0.keys()),
    'Precision': list(precision_0.values()),
    'Recall': list(recall_0.values()),
    'F1-score': list(f1_score_0.values())
})

# Plot menggunakan seaborn
df_plot_class_0_melt = df_plot_class_0.melt('Model', var_name='Metric', value_name='Score')
plt.figure(figsize=(30, 6))
sns.barplot(x='Model', y='Score', hue='Metric', data=df_plot_class_0_melt)
plt.title('Comparison of Precision, Recall, and F1-score for Fraud Detection (Class 0)')
plt.savefig('comparison_report_class_0')
plt.show()
